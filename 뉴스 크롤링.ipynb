# %%
import pandas as pd
df = pd.read_csv('데이터몇개만.csv')
df = df.drop_duplicates('apart_code')
df
# Out:
#       Unnamed: 0.1  Unnamed: 0 apart_code  YYYYMM apart__name  \
# 0           282127      285182  A13983712  201201      상계현대3차
# 270         334861      338115  A15004406  201201      당산현대3차
# 539         337311      340577  A15010307  201201      양평현대6차
# 1019        347173      350519  A15101508  201201        신림현대
# 2103        449200      452901  A15807211  201201      목동현대3차
# 2570        495129      499692  A13384301  201202     서울숲한양현대
# 2651        502459      507048  A13510102  201202   청담현대3차아파트
# 2830        527079      531773  A13881302  201202        현대3차
# 2959        541234      545980  A14321001  201202   광장11현대홈타운
# 3048        621027      626228  A13292501  201204      창동현대타운
# 3170        629845      635093  A15009502  201204        현대3차
# 3233        641243      646989  A13873701  201205        현대백조
# 3285        651698      657711  A13887901  201207   송파현대힐스테이트
# 3368        654150      660171  A13204402  201208      창동현대4차
# ...

# %%
# 크롤링시 필요한 라이브러리 불러오기
from bs4 import BeautifulSoup
import requests
import re
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager


# 웹드라이버 설정
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)


# 페이지 url 형식에 맞게 바꾸어 주는 함수 만들기
# 입력된 수를 1, 11, 21, 31 ...만들어 주는 함수
def makePgNum(num):
    if num == 1:
        return num
    elif num == 0:
        return num + 1
    else:
        return num + 9 * (num - 1)


# 크롤링할 url 생성하는 함수 만들기(검색어, 크롤링 시작 페이지, 크롤링 종료 페이지)
def makeUrl(search, start_pg, end_pg):
    if start_pg == end_pg:
        start_page = makePgNum(start_pg)
        url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&start=" + str(
            start_page)
        print("생성url: ", url)
        return url
    else:
        urls = []
        for i in range(start_pg, end_pg + 1):
            page = makePgNum(i)
            url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&start=" + str(page)
            urls.append(url)
        print("생성url: ", urls)
        return urls

# %%
list(df['apart__name'])[0:6]
# Out:
# ['상계현대3차', '당산현대3차', '양평현대6차', '신림현대', '목동현대3차', '서울숲한양현대']

# %%
list(df['apart__name'])[6:]
# Out:
# ['청담현대3차아파트',
#  '현대3차',
#  '광장11현대홈타운',
#  '창동현대타운',
#  '현대3차',
#  '현대백조',
#  '송파현대힐스테이트',
#  '창동현대4차',
#  '현대백조']

# %%
##########뉴스크롤링 시작###################

# 검색어 입력
for h in list(df['apart__name'])[0:6]:
    search = h

    # 검색 시작할 페이지 입력
    page = int(1)  # ex)1 =1페이지,2=2페이지...
    page2 = int(5)  # ex)1 =1페이지,2=2페이지...

    # naver url 생성
    search_urls = makeUrl(search, page, page2)

    ## selenium으로 navernews만 뽑아오기##

    # 버전에 상관 없이 os에 설치된 크롬 브라우저 사용
    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.implicitly_wait(3)

    # selenium으로 검색 페이지 불러오기 #

    naver_urls = []

    for i in search_urls:
        driver.get(i)
        time.sleep(1)  # 대기시간 변경 가능

        # 네이버 기사 눌러서 제목 및 본문 가져오기#
        # 네이버 기사가 있는 기사 css selector 모아오기
        a = driver.find_elements(By.CSS_SELECTOR, 'a.info')

        # 위에서 생성한 css selector list 하나씩 클릭하여 본문 url얻기
        for i in a:
            i.click()

            # 현재탭에 접근
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(3)  # 대기시간 변경 가능

            # 네이버 뉴스 url만 가져오기

            url = driver.current_url
            print(url)

            if "news.naver.com" in url:
                naver_urls.append(url)

            else:
                pass
            # 현재 탭 닫기
            driver.close()
            # 다시처음 탭으로 돌아가기(매우 중요!!!)
            driver.switch_to.window(driver.window_handles[0])

    print(naver_urls)

    ###naver 기사 본문 및 제목 가져오기###

    # ConnectionError방지
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/98.0.4758.102"}

    titles = []
    contents = []
    for i in naver_urls:
        original_html = requests.get(i, headers=headers)
        html = BeautifulSoup(original_html.text, "html.parser")
        # 검색결과확인시
        # print(html)

        # 뉴스 제목 가져오기
        title = html.select("div#ct > div.media_end_head.go_trans > div.media_end_head_title > h2")
        # list합치기
        title = ''.join(str(title))
        # html태그제거
        pattern1 = '<[^>]*>'
        title = re.sub(pattern=pattern1, repl='', string=title)
        titles.append(title)

        # 뉴스 본문 가져오기

        content = html.select("div#dic_area")

        # 기사 텍스트만 가져오기
        # list합치기
        content = ''.join(str(content))

        # html태그제거 및 텍스트 다듬기
        content = re.sub(pattern=pattern1, repl='', string=content)
        pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
        content = content.replace(pattern2, '')

        contents.append(content)

    print(titles)
    print(contents)
    globals()["df_{}".format(h)] = pd.DataFrame({'title': titles, 'link': naver_urls, 'content': contents})
    globals()["df_{}".format(h)].to_csv('NaverNews_%s.csv' % h, index=False, encoding='utf-8-sig')

    # 데이터프레임으로 정리(titles,url,contents)
# Out:
# 생성url:  ['https://search.naver.com/search.naver?where=news&sm=tab_pge&query=상계현대3차&start=1', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=상계현대3차&start=11', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=상계현대3차&start=21', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=상계현대3차&start=31', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=상계현대3차&start=41']
# C:\Users\46861\AppData\Local\Temp\ipykernel_18960\2905751394.py:17: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# https://theguru.co.kr/index.html
# https://www.news1.kr/
# https://n.news.naver.com/mnews/article/421/0006286737?sid=101
# https://newsis.com/
# https://n.news.naver.com/mnews/article/003/0007999587?sid=101
# https://www.econovill.com/
# http://www.naeil.com/
# https://www.mk.co.kr/economy/
# ...

# %%
##########뉴스크롤링 시작###################

# 검색어 입력
for h in list(df['apart__name'])[8:]:
    search = h

    # 검색 시작할 페이지 입력
    page = int(1)  # ex)1 =1페이지,2=2페이지...
    page2 = int(5)  # ex)1 =1페이지,2=2페이지...

    # naver url 생성
    search_urls = makeUrl(search, page, page2)

    ## selenium으로 navernews만 뽑아오기##

    # 버전에 상관 없이 os에 설치된 크롬 브라우저 사용
    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.implicitly_wait(3)

    # selenium으로 검색 페이지 불러오기 #

    naver_urls = []

    for i in search_urls:
        driver.get(i)
        time.sleep(1)  # 대기시간 변경 가능

        # 네이버 기사 눌러서 제목 및 본문 가져오기#
        # 네이버 기사가 있는 기사 css selector 모아오기
        a = driver.find_elements(By.CSS_SELECTOR, 'a.info')

        # 위에서 생성한 css selector list 하나씩 클릭하여 본문 url얻기
        for i in a:
            i.click()

            # 현재탭에 접근
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(3)  # 대기시간 변경 가능

            # 네이버 뉴스 url만 가져오기

            url = driver.current_url
            print(url)

            if "news.naver.com" in url:
                naver_urls.append(url)

            else:
                pass
            # 현재 탭 닫기
            driver.close()
            # 다시처음 탭으로 돌아가기(매우 중요!!!)
            driver.switch_to.window(driver.window_handles[0])

    print(naver_urls)

    ###naver 기사 본문 및 제목 가져오기###

    # ConnectionError방지
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/98.0.4758.102"}

    titles = []
    contents = []
    for i in naver_urls:
        original_html = requests.get(i, headers=headers)
        html = BeautifulSoup(original_html.text, "html.parser")
        # 검색결과확인시
        # print(html)

        # 뉴스 제목 가져오기
        title = html.select("div#ct > div.media_end_head.go_trans > div.media_end_head_title > h2")
        # list합치기
        title = ''.join(str(title))
        # html태그제거
        pattern1 = '<[^>]*>'
        title = re.sub(pattern=pattern1, repl='', string=title)
        titles.append(title)

        # 뉴스 본문 가져오기

        content = html.select("div#dic_area")

        # 기사 텍스트만 가져오기
        # list합치기
        content = ''.join(str(content))

        # html태그제거 및 텍스트 다듬기
        content = re.sub(pattern=pattern1, repl='', string=content)
        pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
        content = content.replace(pattern2, '')

        contents.append(content)

    print(titles)
    print(contents)
    globals()["df_{}".format(h)] = pd.DataFrame({'title': titles, 'link': naver_urls, 'content': contents})
    globals()["df_{}".format(h)].to_csv('NaverNews_%s.csv' % h, index=False, encoding='utf-8-sig')

    # 데이터프레임으로 정리(titles,url,contents)
# Out:
# 생성url:  ['https://search.naver.com/search.naver?where=news&sm=tab_pge&query=광장11현대홈타운&start=1', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=광장11현대홈타운&start=11', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=광장11현대홈타운&start=21', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=광장11현대홈타운&start=31', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=광장11현대홈타운&start=41']
# C:\Users\46861\AppData\Local\Temp\ipykernel_18960\1749891657.py:17: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# https://www.econovill.com/
# https://www.newspim.com/
# https://www.sedaily.com/
# https://n.news.naver.com/mnews/article/011/0000059509?sid=101
# https://www.sedaily.com/
# https://n.news.naver.com/mnews/article/011/0000059510?sid=101
# https://www.sedaily.com/
# ...

# %%
apart_news = pd.read_csv('NaverNews_광장11현대홈타운.csv')

# %%
apart_news
# Out:
#                                                 title  \
# 0              [[2004 한국건축문화大賞] 주거부문본상 '광장 11차 현대홈타운]
# 1             [[2004 한국건축문화大賞] '광장 11차 현대홈타운' 설계자 인터]
# 2             [[2004 한국건축문화大賞] '광장 11차 현대홈타운' 시공자 인터]
# 3   [[Real Estate] 강남 안 부러운 강북 ‘10억 아파트’ 어디? 30평대 ...
# 4    [집값 주춤하다더니 한강변은 ‘천장 뚫기’…비강남 ‘광동성’도 국민 평형 20억 기본]
# 5              [강동구도 '국평 20억 클럽' 가입…마용성 이어 非강남권서도 속속]
# 6           ["한방에 1억 떨어졌다"…철옹성 같았던 서울 집값이 흔들, 급매물 등장]
# 7                      [실거래가 1억~2억씩 ‘뚝뚝’… 서울도 급매물 출현]
# 8                         [비강남권 ‘국민평형’ 20억원 돌파 ‘줄줄이’]
# 9                  [전세대책 효과없나…강남 중형아파트 전세가 '20억' 넘었다]
# 10                [[단독]강남 아파트 전용 84㎡ '전세 20억' 시대 열렸다]
# 11                    [아리팍 84㎡ 전셋값 20억…비강남권도 10억대 시대]
# 12                       [가을 '전세대란' 현실화…매물 줄고 가격은 급등]
# 13                             [임대차법 후폭풍… 강북도 전세 10억]
# 14                   [“전세가 기가막혀”…비강남권 84㎡ 아파트도 10억시대]
# 15        [비강남권 84㎡ 아파트 전셋값도 ‘10억’ 시대… 강남은 20억 향해 간다]
# ...

# %%
pd.read_csv('NaverNews_현대3차.csv')
# Out:
#                                                 title  \
# 0                                                  []
# 1                                                  []
# 2                            [대구사이버대, 제3차 발전자문위원회 열어]
# 3                    [KRISO, 현대중공업그룹과 조선해양산업 미래 구상한다]
# 4                   [KRISO, 현대중공업그룹과 조선해양 R&amp;D 맞손]
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                       [당산도 정비사업 훈풍…현대3차 예안진 문턱 넘었다]
# 9                                                  []
# 10      [[단독]'여의도 옆' 당산동 정비사업 잰걸음…'당산현대3차' 예비안전진단 통과]
# 11                                                 []
# 12                                                 []
# 13  [[영상] “中, 펠로시 구실로 軍 현대화 과시…1~3차 대만위기 ‘굴욕’ 청산” ...
# 14                       [우동3구역 시공사 우선협상대상자로 현대건설 선정]
# 15                                                 []
#
# ...
